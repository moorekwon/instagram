# %%
import boto3

secret_name = 'wps'
region_name = 'ap-northeast-2'

# access_key, secreat_access_key를 사용한 session 생성
session = boto3.session.Session(
    aws_access_key_id='',
    aws_secret_access_key='',
    region_name=region_name
)

# profile을 사용한 session 생성
session = boto3.session.Session(
    profile_name='wps-secrets-manager',
    region_name=region_name
)
# Out:
# ---------------------------------------------------------------------------
# ProfileNotFound                           Traceback (most recent call last)
# <ipython-input-1-4113011762e2> in <module>
#      14 session = boto3.session.Session(
#      15     profile_name='wps-secrets-manager',
# ---> 16     region_name=region_name
#      17 )
#
# ~/.pyenv/versions/wps-instagram-env/lib/python3.7/site-packages/boto3/session.py in __init__(self, aws_access_key_id, aws_secret_access_key, aws_session_token, region_name, botocore_session, profile_name)
#      78         self.resource_factory = ResourceFactory(
#      79             self._session.get_component('event_emitter'))
# ---> 80         self._setup_loader()
#      81         self._register_default_handlers()
#      82
#
# ~/.pyenv/versions/wps-instagram-env/lib/python3.7/site-packages/boto3/session.py in _setup_loader(self)
#     118         Setup loader paths so that we can load resources.
#     119         """
# ...

# %%
# SecretManager를 사용하기 위한 Client 생성
client = session.client(
    service_name='secretsmanager',
    region_name=region_name
)

# %%
client.get_secret_value(SecretId='wps')
# Out:
# ---------------------------------------------------------------------------
# NoCredentialsError                        Traceback (most recent call last)
# <ipython-input-7-f4f09f3f9137> in <module>
# ----> 1 client.get_secret_value(SecretId='wps')
#
# ~/.pyenv/versions/wps-instagram-env/lib/python3.7/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     274                     "%s() only accepts keyword arguments." % py_operation_name)
#     275             # The "self" in this scope is referring to the BaseClient.
# --> 276             return self._make_api_call(operation_name, kwargs)
#     277
#     278         _api_call.__name__ = str(py_operation_name)
#
# ~/.pyenv/versions/wps-instagram-env/lib/python3.7/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     571         else:
#     572             http, parsed_response = self._make_request(
# --> 573                 operation_model, request_dict, request_context)
# ...

# %%
import json
secret_string = client.get_secret_value(SecretId='wps')['SecretString']
secrets_data = json.loads(secret_string)
secrets = secrets_data['instagram']
secrets
# Out:
# ---------------------------------------------------------------------------
# NoCredentialsError                        Traceback (most recent call last)
# <ipython-input-8-3f4d0dafc046> in <module>
#       1 import json
# ----> 2 secret_string = client.get_secret_value(SecretId='wps')['SecretString']
#       3 secrets_data = json.loads(secret_string)
#       4 secrets = secrets_data['instagram']
#       5 secrets
#
# ~/.pyenv/versions/wps-instagram-env/lib/python3.7/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     274                     "%s() only accepts keyword arguments." % py_operation_name)
#     275             # The "self" in this scope is referring to the BaseClient.
# --> 276             return self._make_api_call(operation_name, kwargs)
#     277
#     278         _api_call.__name__ = str(py_operation_name)
#
# ~/.pyenv/versions/wps-instagram-env/lib/python3.7/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
# ...
